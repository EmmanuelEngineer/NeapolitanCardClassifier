# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
import utilities as ut
import cv2
import joblib

images_paths = ut.images_paths("Images/DatasetCropped/")

labels = []
hu_moments = []
for path in images_paths:
    sample_properties = ut.label_properties(path)
    if sample_properties["value"]+sample_properties["seed"] not in ["AO","AC","AB","AS","2S","3S","3B"]:#
        continue
    image = cv2.imread(path)
    contours = ut.preprocess_image(image)
    moments = cv2.moments(contours[0])
    hu_moments.append(cv2.HuMoments(moments).flatten())
    labels.append(sample_properties["value"]+sample_properties["seed"])

#X_train, X_test, y_train, y_test = train_test_split(hu_moments, labels, test_size=0.2, random_state=42)
X_train = hu_moments
y_train = labels
print(X_train)
print("----------")
print(y_train)
# Out:
# [array([ 1.60406884e-03,  7.18934306e-07,  1.07099356e-12,  6.90008395e-12,
#         1.86630992e-23,  5.79963954e-15, -1.87951960e-24]), array([1.12452831e-03, 4.74613334e-07, 1.86288044e-11, 2.18745931e-12,
#        1.39230489e-23, 5.54693638e-16, 1.06554483e-24]), array([ 1.28619188e-03,  1.37774517e-07,  1.66127742e-13,  1.25436394e-11,
#         1.78803836e-23, -1.22233949e-16, -2.85837496e-24]), array([ 1.50753682e-03,  3.07469518e-07,  6.63673847e-13,  1.25691435e-11,
#         3.62673006e-23,  5.04722359e-15, -1.59701318e-24]), array([1.00905991e-03, 1.89556830e-07, 3.42366092e-13, 4.15467605e-13,
#        1.39532286e-25, 1.77101350e-16, 7.12994397e-26]), array([ 1.30275011e-03,  6.81013291e-07,  4.53694106e-11,  1.03348333e-11,
#         2.23784646e-22,  8.09652122e-15, -1.22384365e-24]), array([ 1.57098292e-03,  8.37679952e-07,  2.46130040e-10,  1.67484226e-10,
# ...

# %%
clf = svm.SVC()
clf.fit(X_train, y_train)
predictions = clf.predict(X_test)
print("Accuracy:", accuracy_score(y_test, predictions))
print("Classification Report:")
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 0.0
# Classification Report:
#               precision    recall  f1-score   support
#
#           2S       0.00      0.00      0.00       1.0
#           3B       0.00      0.00      0.00       0.0
#           3S       0.00      0.00      0.00       1.0
#           AC       0.00      0.00      0.00       1.0
#           AO       0.00      0.00      0.00       2.0
#
#     accuracy                           0.00       5.0
#    macro avg       0.00      0.00      0.00       5.0
# weighted avg       0.00      0.00      0.00       5.0
# /home/emmavico/Desktop/Codice/project_venv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
joblib.dump(clf, f"{ut.Config.working_directory}first_model.joblib")
# Out:
# ['workingDirectory/first_model.joblib']

# %%
test_image = cv2.imread('Images/Cards/AS.jpg')
contours = ut.preprocess_image(test_image)
moments = cv2.moments(contours[0])
hu_moment=[cv2.HuMoments(moments).flatten()]

print(clf.predict(hu_moment))
# Out:
# ['9C']

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'C': [0.1, 1, 10, 100], # Regularization parameter
    'gamma': [1, 0.1, 0.01, 0.001], # Kernel coefficient for 'rbf', 'poly' and 'sigmoid'.
    'kernel': ['rbf', 'poly', 'sigmoid'] # Specifies the kernel type to be used in the algorithm
}
grid_svm = GridSearchCV(svm.SVC(), param_grid, refit=True, verbose=2, cv=5)
grid_svm.fit(X_train, y_train)

print("Best Parameters:", grid_svm.best_params_)
print("Best Estimator:", grid_svm.best_estimator_)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END .....................C=0.1, gamma=1, kernel=sigmoid; total time=   0.0s
# ...

# %%
best_predictions = grid_svm.predict(X_train)
print("Accuracy with Tuned Parameters:", accuracy_score(y_train, best_predictions))
print("Classification Report with Tuned Parameters:")
print(classification_report(y_train, best_predictions))
# Out:
# Accuracy with Tuned Parameters: 0.5
# Classification Report with Tuned Parameters:
#               precision    recall  f1-score   support
#
#           2S       0.33      0.40      0.36         5
#           3B       0.50      0.20      0.29         5
#           3S       0.00      0.00      0.00         4
#           AC       0.50      0.80      0.62         5
#           AO       0.62      1.00      0.77         5
#
#     accuracy                           0.50        24
#    macro avg       0.39      0.48      0.41        24
# weighted avg       0.41      0.50      0.42        24
# /home/emmavico/Desktop/Codice/project_venv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
test_image = cv2.imread('Images/Cards/AC.jpg')
contours = ut.preprocess_image(test_image)
moments = cv2.moments(contours[0])
hu_moment=[cv2.HuMoments(moments).flatten()]

print(grid_svm.predict(hu_moment))
# Out:
# ['AC']
